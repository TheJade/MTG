# %%
import requests
from bs4 import BeautifulSoup

URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find(id="ResultsContainer")

job_elements = results.find_all("div", class_="card-content")

for job_element in job_elements:
    title_element = job_element.find("h2", class_="title")
    company_element = job_element.find("h3", class_="company")
    location_element = job_element.find("p", class_="location")
    print(title_element.text)
    print(company_element.text)
    print(location_element.text)
    print()
# Out:
# Senior Python Developer
# Payne, Roberts and Davis
#
#         Stewartbury, AA
#
#
# Energy engineer
# Vasquez-Davidson
#
#         Christopherville, AA
#
#
# Legal executive
# Jackson, Chambers and Levy
#
#         Port Ericaburgh, AA
#
#
# Fitness centre manager
# Savage-Bradley
#
#         East Seanview, AP
#
#
# Product manager
# Ramirez Inc
#
#         North Jamieview, AP
#
#
# Medical technical officer
# Rogers-Yates
#
#         Davidville, AP
#
#
# Physiological scientist
# Kramer-Klein
#
#         South Christopher, AE
#
#
# Textile designer
# Meyers-Johnson
#
#         Port Jonathan, AE
#
#
# Television floor manager
# Hughes-Williams
#
#         Osbornetown, AE
#
#
# Waste management officer
# Jones, Williams and Villa
#
#         Scotttown, AP
#
#
# Software Engineer (Python)
# Garcia PLC
#
#         Ericberg, AE
#
#
# Interpreter
# Gregory and Sons
#
#         Ramireztown, AE
#
#
# Architect
# Clark, Garcia and Sosa
#
#         Figueroaview, AA
#
#
# Meteorologist
# Bush PLC
#
#         Kelseystad, AA
#
#
# Audiological scientist
# Salazar-Meyers
#
#         Williamsburgh, AE
#
#
# English as a second language teacher
# Parker, Murphy and Brooks
#
#         Mitchellburgh, AE
#
#
# Surgeon
# Cruz-Brown
#
#         West Jessicabury, AA
#
#
# Equities trader
# Macdonald-Ferguson
#
#         Maloneshire, AE
#
#
# Newspaper journalist
# Williams, Peterson and Rojas
#
#         Johnsonton, AA
#
#
# Materials engineer
# Smith and Sons
#
#         South Davidtown, AP
#
#
# Python Programmer (Entry-Level)
# Moss, Duncan and Allen
#
#         Port Sara, AE
#
#
# Product/process development scientist
# Gomez-Carroll
#
#         Marktown, AA
#
#
# Scientist, research (maths)
# Manning, Welch and Herring
#
#         Laurenland, AE
#
#
# Ecologist
# Lee, Gutierrez and Brown
#
#         Lauraton, AP
#
#
# Materials engineer
# Davis, Serrano and Cook
#
#         South Tammyberg, AP
#
#
# Historic buildings inspector/conservation officer
# Smith LLC
#
#         North Brandonville, AP
#
#
# Data scientist
# Thomas Group
#
#         Port Robertfurt, AA
#
#
# Psychiatrist
# Silva-King
#
#         Burnettbury, AE
#
#
# Structural engineer
# Pierce-Long
#
#         Herbertside, AA
#
#
# Immigration officer
# Walker-Simpson
#
#         Christopherport, AP
#
#
# Python Programmer (Entry-Level)
# Cooper and Sons
#
#         West Victor, AE
#
#
# Neurosurgeon
# Donovan, Gonzalez and Figueroa
#
#         Port Aaron, AP
#
#
# Broadcast engineer
# Morgan, Butler and Bennett
#
#         Loribury, AA
#
#
# Make
# Snyder-Lee
#
#         Angelastad, AP
#
#
# Nurse, adult
# Harris PLC
#
#         Larrytown, AE
#
#
# Air broker
# Washington PLC
#
#         West Colin, AP
#
#
# Editor, film/video
# Brown, Price and Campbell
#
#         West Stephanie, AP
#
#
# Production assistant, radio
# Mcgee PLC
#
#         Laurentown, AP
#
#
# Engineer, communications
# Dixon Inc
#
#         Wrightberg, AP
#
#
# Sales executive
# Thompson, Sheppard and Ward
#
#         Alberttown, AE
#
#
# Software Developer (Python)
# Adams-Brewer
#
#         Brockburgh, AE
#
#
# Futures trader
# Schneider-Brady
#
#         North Jason, AE
#
#
# Tour manager
# Gonzales-Frank
#
#         Arnoldhaven, AE
#
#
# Cytogeneticist
# Smith-Wong
#
#         Lake Destiny, AP
#
#
# Designer, multimedia
# Pierce-Herrera
#
#         South Timothyburgh, AP
#
#
# Trade union research officer
# Aguilar, Rivera and Quinn
#
#         New Jimmyton, AE
#
#
# Chemist, analytical
# Lowe, Barnes and Thomas
#
#         New Lucasbury, AP
#
#
# Programmer, multimedia
# Lewis, Gonzalez and Vasquez
#
#         Port Cory, AE
#
#
# Engineer, broadcasting (operations)
# Taylor PLC
#
#         Gileston, AA
#
#
# Teacher, primary school
# Oliver, Jones and Ramirez
#
#         Cindyshire, AA
#
#
# Python Developer
# Rivera and Sons
#
#         East Michaelfort, AA
#
#
# Manufacturing systems engineer
# Garcia PLC
#
#         Joybury, AE
#
#
# Producer, television/film/video
# Johnson, Wells and Kramer
#
#         Emmatown, AE
#
#
# Scientist, forensic
# Gonzalez LLC
#
#         Colehaven, AP
#
#
# Bonds trader
# Morgan, White and Macdonald
#
#         Port Coryton, AE
#
#
# Editorial assistant
# Robinson-Fitzpatrick
#
#         Amyborough, AA
#
#
# Photographer
# Waters, Wilson and Hoover
#
#         Reynoldsville, AA
#
#
# Retail banker
# Hill LLC
#
#         Port Billy, AP
#
#
# Jewellery designer
# Li-Gregory
#
#         Adamburgh, AA
#
#
# Ophthalmologist
# Fisher, Ryan and Coleman
#
#         Wilsonmouth, AA
#
#
# Back-End Web Developer (Python, Django)
# Stewart-Alexander
#
#         South Kimberly, AA
#
#
# Licensed conveyancer
# Abbott and Sons
#
#         Benjaminland, AP
#
#
# Futures trader
# Bryant, Santana and Davenport
#
#         Zacharyport, AA
#
#
# Counselling psychologist
# Smith PLC
#
#         Port Devonville, AE
#
#
# Insurance underwriter
# Patterson-Singh
#
#         East Thomas, AE
#
#
# Engineer, automotive
# Martinez-Berry
#
#         New Jeffrey, AP
#
#
# Producer, radio
# May, Taylor and Fisher
#
#         Davidside, AA
#
#
# Dispensing optician
# Bailey, Owen and Thompson
#
#         Jamesville, AA
#
#
# Designer, fashion/clothing
# Vasquez Ltd
#
#         New Kelly, AP
#
#
# Chartered loss adjuster
# Leblanc LLC
#
#         Lake Antonio, AA
#
#
# Back-End Web Developer (Python, Django)
# Jackson, Ali and Mckee
#
#         New Elizabethside, AA
#
#
# Forest/woodland manager
# Blankenship, Knight and Powell
#
#         Millsbury, AE
#
#
# Clinical cytogeneticist
# Patton, Haynes and Jones
#
#         Lloydton, AP
#
#
# Print production planner
# Wood Inc
#
#         Port Jeremy, AA
#
#
# Systems developer
# Collins Group
#
#         New Elizabethtown, AA
#
#
# Graphic designer
# Flores-Nelson
#
#         Charlesstad, AE
#
#
# Writer
# Mitchell, Jones and Olson
#
#         Josephbury, AE
#
#
# Field seismologist
# Howard Group
#
#         Seanfurt, AA
#
#
# Chief Strategy Officer
# Kramer-Edwards
#
#         Williambury, AA
#
#
# Air cabin crew
# Berry-Houston
#
#         South Jorgeside, AP
#
#
# Python Programmer (Entry-Level)
# Mathews Inc
#
#         Robertborough, AP
#
#
# Warden/ranger
# Riley-Johnson
#
#         South Saratown, AP
#
#
# Sports therapist
# Spencer and Sons
#
#         Hullview, AA
#
#
# Arts development officer
# Camacho-Sanchez
#
#         Philipland, AP
#
#
# Printmaker
# Oliver and Sons
#
#         North Patty, AE
#
#
# Health and safety adviser
# Eaton PLC
#
#         North Stephen, AE
#
#
# Manufacturing systems engineer
# Stanley-Frederick
#
#         Stevensland, AP
#
#
# Programmer, applications
# Bradley LLC
#
#         Reyesstad, AE
#
#
# Medical physicist
# Parker, Goodwin and Zavala
#
#         Bellberg, AP
#
#
# Media planner
# Kim-Miles
#
#         North Johnland, AE
#
#
# Software Developer (Python)
# Moreno-Rodriguez
#
#         Martinezburgh, AE
#
#
# Surveyor, land/geomatics
# Brown-Ortiz
#
#         Joshuatown, AE
#
#
# Legal executive
# Hartman PLC
#
#         West Ericstad, AA
#
#
# Librarian, academic
# Brooks Inc
#
#         Tuckertown, AE
#
#
# Barrister
# Washington-Castillo
#
#         Perezton, AE
#
#
# Museum/gallery exhibitions officer
# Nguyen, Yoder and Petty
#
#         Lake Abigail, AE
#
#
# Radiographer, diagnostic
# Holder LLC
#
#         Jacobshire, AP
#
#
# Database administrator
# Yates-Ferguson
#
#         Port Susan, AE
#
#
# Furniture designer
# Ortega-Lawrence
#
#         North Tiffany, AA
#
#
# Ship broker
# Fuentes, Walls and Castro
#
#         Michelleville, AP

# %% [markdown]
# # testing

# %%
import requests
from bs4 import BeautifulSoup

url = "https://mtgdecks.net/Commander/tournaments"

response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")

results = soup.find()

# # Find all the tournament rows in the table
# tournament_rows = soup.find_all("tr", class_="altrow")

# # Loop through each tournament row and extract the relevant data
# for row in tournament_rows:
#     tournament_date = row.find("td", class_="date").text.strip()
#     tournament_name = row.find("td", class_="name").text.strip()
#     tournament_location = row.find("td", class_="location").text.strip()
#     tournament_format = row.find("td", class_="format").text.strip()
#     tournament_url = row.find("td", class_="name").find("a")["href"]

#     # Do something with the data (e.g. print it)
#     print(f"Date: {tournament_date}")
#     print(f"Name: {tournament_name}")
#     print(f"Location: {tournament_location}")
#     print(f"Format: {tournament_format}")
#     print(f"URL: {tournament_url}")

# %%
results.find_all('a')
# Out:
# []

# %%
soup.find_all("tr", class_="hidden-xs")
# Out:
# []

# %%
soup.find_all('h1')
# Out:
# []

# %%
soup.p

# %%
print(results.prettify())
# Out:
# <html lang="en-US">
#  <head>
#   <title>
#    Just a moment...
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex,nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
#  </head>
#  <body class="no-js">
#   <div class="main-wrapper" role="main">
#    <div class="main-content">
#     <noscript>
#      <div id="challenge-error-title">
#       <div class="h2">
#        <span class="icon-wrapper">
#         <div class="heading-icon warning-icon">
#         </div>
#        </span>
#        <span id="challenge-error-text">
#         Enable JavaScript and cookies to continue
#        </span>
#       </div>
#      </div>
#     </noscript>
#     <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/managed/nojs/transparent.gif?ray=7ad058e69e6501e2')">
#     </div>
#     <form action="/Commander/tournaments?__cf_chl_f_tk=eHi_qJ3V.0RSw3ePrx96AEk725wpkmhaYedXUCM67Y0-1679675935-0-gaNycGzNCns" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#      <input name="md" type="hidden" value="B15bOTo_GMegOsXxp39UGdlSWB51LOqWNXbrF0kRetc-1679675935-0-ARO8rAwEU8zh2cBhZ0W0to0omSNBhG6OOoWIRAWwf-GDMuY7344ORHAKW0zs6a8jgjuQUYz-LOnQmVyLYeXSIejqCOLCZOVt9HR07bWSwwVU5yMIVSPQkZY6oFtJd6I_zH3YtXEREsLYB072XFuD5uCi0wXu2dQLzlSGkOzB3esY2WKwnbJ13wHIxJaAcpxvWpaagKwJfKZmD3kyutCc7BJ8Rj5Y4k7eOScDNbimt4nlh1qIOTCsLU0qVoEeL4WsD0VMcaa6tBMEkUc4fY4rnQmM3Vrn8YGixHpB0EAGhuwXldKIxhlvSIBrLO2hceTi0vlGI9VbTg2zeASHPbxSF8zLXZ18YusV7IZHZoNxEtp1wIp-Wq2CCfraYnA9PbHJVHFNsbOzTgO-Y4kBufIUH_7EgDIqd6bJIjQ-w_gmat8K_00v_U5aQ7hejLNuQmmc4zT7OwZPnJ3eMYwdWbwPjDewLqJWu4G01DIJ1SrbyKwcWfeZ1LUIboSuxsK71HNxxGzhkUCC-bZiH6amA6imOW1Ml7Dk--ySo0rYjtEdcW_gijoTCS0ohDuCAN185c3-NSu0iHph6o5YVjVe646s0aQ-WN6p1wdU7TrDLuiLnhwHR8d8GEmdqK3aPa0nh2BuMJt8jR2vVxeQCUlGi0nZYtZXjVnNQ0sm9K9mvYRl1nF4v-g0VfiPb8pWbWwcEwf3n62Ns21Ir1rNDCLEhnUWHTcFeeYhmeuIE1b-wUBXnTeY5MxRZ5LJ76cImyxuIgqjOi4a4CMfHytz0_sO580VQ36j753TV0JgKqq6xjLyS3kFfOpM3QTV-IjGyFtuARCF0ZMkbTVlgNlQZzcmjHvih3mBqTsQ_DwZnVFEaG-jimIXJr9Pf-j1KxmDcfQaZDpw3DHbdSC69pJQaYw98Cd6iDKnhwg2wBvWtAtyRX-Dq9s3O2v0_otvi4aUwwZjf0b-irwd6vVLk2np3X9EsBIIjT3NT3q8-srM1xuHXOmEulc62GGH23WQnnzAjXD-gxfpHNg-nmm6VUpRQ0EBD7hzl8w27ybjpgFo-G6s4mn2QvGiEOwwhSZk0V671txsvLIqN8z0nqaG7nYNhYGA_ra87nx42vIbk8Fkz29xWQsvKPi3AyZ5oIRaKb9ucyCTurXhV2EyeRMXuIeGwXPsj8jpmrX8kJLXj4Gkio5f-NcXxvxXd-9NqJN8AWlWlfdUANUO6styan_d-VYFbANt0MBP--Ji9zcZI-6tt9mq8t7R7NCY9ODTC24QNO6vwms3VYBWOPMtieLfyOSE9Wk8Oo_KbmoBK0ZJ1tp7ND6sNKh9VLCHUrKd7HGpwTGdfC7EpQCrGlxj_j8Df3Qftx2LLwjnMO-gQaCHV3Dvuud2y0vumIbzmOOHpcrKGTtubqVjK3iOIZknOALyuyZgrRI4jHzFFcd9MMyVWC1Ti_tG9ycQbJGNkt8-icC24MYlutpPC4snpny5eVRmKvY3-NhTmMzMaBHnjEeenDcWBUlVZ7x1_4bT-UgquzW0hszdm5OzwF_wL0XfUbYgcFCxSrHUmvL-N7nlucdfrYhRVXL60nJD8aH3yp9gpP1M6DDWbK8TXO0NBMI6FUiOy-_E0n1sjfX-vOsZQkKNG-oy74TkF03jmXF7T57Qu-QrwPnDd5yWlgiT7xGPO2xT0qC5LINbxWz43MyDCWem8fzEJgA-nqCM2ZAWlBmLEBCfFOGrYW_kPhtFKSl4UurSkUH36yfuS2-14CxryKAEpHxtwSDYF-NFfNXY1553MDojS9o5_IaNiVUUKvj2bh4rtYC02-NPD7M4Wzb6JjFGpjSenBYLe4fpKgZR8TgjQDQGITXWgWSQq3V5Mb-FwcXWVjTso3V8DKjXhJqofaWnC_aX1H7fec-DDvZn32-Z099ghOe1vAlXTt3T9nVZ93anr0c8uohwZye0LISFDtEWdSdx-H2hrEPB7F0ccnVNjx95PvYcQ-ziBZD4Vkqk27xWHn7pzoxnU8YNqVHse9-C-Xizs68vGPBfncWEuFvNzN25NGXmDi9NRwYXfkyUKxIypLAC_s99BlvGZ48lXRJaYa8wGndg-VfzNRWsfofpMcIthxGXIq0eHXa4ARsymgPk-nBCJ7B2cf1KhHk_LtM7W0E09l2AfB8LCaRHESljFg5sIA6sZRBNro_EA71TdOW9mO__1ctpugLWAmN0RQ__xrdy1SKtpVvT5jFZ9lOCrHMvEKeOCNIgcxS1JAYLCTWmHAEcw18AzdzFnaLNBfZm3R1W2UWT7oBijU7R5K67vS4dCSXgWauqjxLQYjaAjO1xi1tIJAxCRY_3y2PjsdQ6UY1JnVEy86LZQXpoAT9w2NcB8AoSXAuEtIHD653eiqV2hjvJlb9YzLEkw1ct8U6JqePv8E4GvRfGbG9Bwf-kK4BagLs4DE36PzKvwgPmOQ7asoFO_JYc-VdvupXn4A9UKiAthWcA_fCFxUUrujJfzBasv9RaKJze6lLr5wQuq2VkNXXzyawp78MMB7nLipnEAp18mskNzqbxIIvU9spET175vfx7yQ7pubO9Rkllxz6I5XZ39HsPmbuRMqjao5JTDFHMF05apG9F5F2ky-UjUn0PkMGaznPwbqG9Tg"/>
#     </form>
#    </div>
#   </div>
#   <script>
#    (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cZone: 'mtgdecks.net',
#             cType: 'managed',
#             cNounce: '40743',
#             cRay: '7ad058e69e6501e2',
#             cHash: '9de604cccd713dd',
#             cUPMDTk: "\/Commander\/tournaments?__cf_chl_tk=eHi_qJ3V.0RSw3ePrx96AEk725wpkmhaYedXUCM67Y0-1679675935-0-gaNycGzNCns",
#             cFPWv: 'b',
#             cTTimeMs: '1000',
#             cMTimeMs: '0',
#             cTplV: 5,
#             cTplB: 'cf',
#             cK: "",
#             cRq: {
#                 ru: 'aHR0cHM6Ly9tdGdkZWNrcy5uZXQvQ29tbWFuZGVyL3RvdXJuYW1lbnRz',
#                 ra: 'cHl0aG9uLXJlcXVlc3RzLzIuMjguMQ==',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY3OTY3NTkzNS43NzYwMDA=',
#                 m: 'xKVXDxit+DDhVOYx2zrhs+hNccmskPct/cQuNgqpecg=',
#                 i1: '+rbbf+oRSDRnjd18lzEaiw==',
#                 i2: 'mBYfjrxuqdSlBJHDAfKsoA==',
#                 zh: 'E1sOE47J/NwOldWxeIJpiiKaYY34wZRmhNkq6w3XN2w=',
#                 uh: 'SLdVolODg++SO356HusO5I/hbfOpiiOxQXj62i/MUkA=',
#                 hh: 'Odc0WggcL1KnIpiAZ+Yz+K13c5TnxM0zZFQfgrM8I80=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7ad058e69e6501e2');
#         trkjs.setAttribute('alt', '');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/b/orchestrate/managed/v1?ray=7ad058e69e6501e2';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, location.href.length - window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/Commander\/tournaments?__cf_chl_rt_tk=eHi_qJ3V.0RSw3ePrx96AEk725wpkmhaYedXUCM67Y0-1679675935-0-gaNycGzNCns" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#   </script>
#  </body>
# </html>
