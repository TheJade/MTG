# %%
import requests
from bs4 import BeautifulSoup

URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find(id="ResultsContainer")

job_elements = results.find_all("div", class_="card-content")

for job_element in job_elements:
    title_element = job_element.find("h2", class_="title")
    company_element = job_element.find("h3", class_="company")
    location_element = job_element.find("p", class_="location")
    print(title_element.text)
    print(company_element.text)
    print(location_element.text)
    print()
# Out:
# Senior Python Developer
# Payne, Roberts and Davis
#
#         Stewartbury, AA
#
#
# Energy engineer
# Vasquez-Davidson
#
#         Christopherville, AA
#
#
# Legal executive
# Jackson, Chambers and Levy
#
#         Port Ericaburgh, AA
#
#
# Fitness centre manager
# Savage-Bradley
#
#         East Seanview, AP
#
#
# Product manager
# Ramirez Inc
#
#         North Jamieview, AP
#
#
# Medical technical officer
# Rogers-Yates
#
#         Davidville, AP
#
#
# Physiological scientist
# Kramer-Klein
#
#         South Christopher, AE
#
#
# Textile designer
# Meyers-Johnson
#
#         Port Jonathan, AE
#
#
# Television floor manager
# Hughes-Williams
#
#         Osbornetown, AE
#
#
# Waste management officer
# Jones, Williams and Villa
#
#         Scotttown, AP
#
#
# Software Engineer (Python)
# Garcia PLC
#
#         Ericberg, AE
#
#
# Interpreter
# Gregory and Sons
#
#         Ramireztown, AE
#
#
# Architect
# Clark, Garcia and Sosa
#
#         Figueroaview, AA
#
#
# Meteorologist
# Bush PLC
#
#         Kelseystad, AA
#
#
# Audiological scientist
# Salazar-Meyers
#
#         Williamsburgh, AE
#
#
# English as a second language teacher
# Parker, Murphy and Brooks
#
#         Mitchellburgh, AE
#
#
# Surgeon
# Cruz-Brown
#
#         West Jessicabury, AA
#
#
# Equities trader
# Macdonald-Ferguson
#
#         Maloneshire, AE
#
#
# Newspaper journalist
# Williams, Peterson and Rojas
#
#         Johnsonton, AA
#
#
# Materials engineer
# Smith and Sons
#
#         South Davidtown, AP
#
#
# Python Programmer (Entry-Level)
# Moss, Duncan and Allen
#
#         Port Sara, AE
#
#
# Product/process development scientist
# Gomez-Carroll
#
#         Marktown, AA
#
#
# Scientist, research (maths)
# Manning, Welch and Herring
#
#         Laurenland, AE
#
#
# Ecologist
# Lee, Gutierrez and Brown
#
#         Lauraton, AP
#
#
# Materials engineer
# Davis, Serrano and Cook
#
#         South Tammyberg, AP
#
#
# Historic buildings inspector/conservation officer
# Smith LLC
#
#         North Brandonville, AP
#
#
# Data scientist
# Thomas Group
#
#         Port Robertfurt, AA
#
#
# Psychiatrist
# Silva-King
#
#         Burnettbury, AE
#
#
# Structural engineer
# Pierce-Long
#
#         Herbertside, AA
#
#
# Immigration officer
# Walker-Simpson
#
#         Christopherport, AP
#
#
# Python Programmer (Entry-Level)
# Cooper and Sons
#
#         West Victor, AE
#
#
# Neurosurgeon
# Donovan, Gonzalez and Figueroa
#
#         Port Aaron, AP
#
#
# Broadcast engineer
# Morgan, Butler and Bennett
#
#         Loribury, AA
#
#
# Make
# Snyder-Lee
#
#         Angelastad, AP
#
#
# Nurse, adult
# Harris PLC
#
#         Larrytown, AE
#
#
# Air broker
# Washington PLC
#
#         West Colin, AP
#
#
# Editor, film/video
# Brown, Price and Campbell
#
#         West Stephanie, AP
#
#
# Production assistant, radio
# Mcgee PLC
#
#         Laurentown, AP
#
#
# Engineer, communications
# Dixon Inc
#
#         Wrightberg, AP
#
#
# Sales executive
# Thompson, Sheppard and Ward
#
#         Alberttown, AE
#
#
# Software Developer (Python)
# Adams-Brewer
#
#         Brockburgh, AE
#
#
# Futures trader
# Schneider-Brady
#
#         North Jason, AE
#
#
# Tour manager
# Gonzales-Frank
#
#         Arnoldhaven, AE
#
#
# Cytogeneticist
# Smith-Wong
#
#         Lake Destiny, AP
#
#
# Designer, multimedia
# Pierce-Herrera
#
#         South Timothyburgh, AP
#
#
# Trade union research officer
# Aguilar, Rivera and Quinn
#
#         New Jimmyton, AE
#
#
# Chemist, analytical
# Lowe, Barnes and Thomas
#
#         New Lucasbury, AP
#
#
# Programmer, multimedia
# Lewis, Gonzalez and Vasquez
#
#         Port Cory, AE
#
#
# Engineer, broadcasting (operations)
# Taylor PLC
#
#         Gileston, AA
#
#
# Teacher, primary school
# Oliver, Jones and Ramirez
#
#         Cindyshire, AA
#
#
# Python Developer
# Rivera and Sons
#
#         East Michaelfort, AA
#
#
# Manufacturing systems engineer
# Garcia PLC
#
#         Joybury, AE
#
#
# Producer, television/film/video
# Johnson, Wells and Kramer
#
#         Emmatown, AE
#
#
# Scientist, forensic
# Gonzalez LLC
#
#         Colehaven, AP
#
#
# Bonds trader
# Morgan, White and Macdonald
#
#         Port Coryton, AE
#
#
# Editorial assistant
# Robinson-Fitzpatrick
#
#         Amyborough, AA
#
#
# Photographer
# Waters, Wilson and Hoover
#
#         Reynoldsville, AA
#
#
# Retail banker
# Hill LLC
#
#         Port Billy, AP
#
#
# Jewellery designer
# Li-Gregory
#
#         Adamburgh, AA
#
#
# Ophthalmologist
# Fisher, Ryan and Coleman
#
#         Wilsonmouth, AA
#
#
# Back-End Web Developer (Python, Django)
# Stewart-Alexander
#
#         South Kimberly, AA
#
#
# Licensed conveyancer
# Abbott and Sons
#
#         Benjaminland, AP
#
#
# Futures trader
# Bryant, Santana and Davenport
#
#         Zacharyport, AA
#
#
# Counselling psychologist
# Smith PLC
#
#         Port Devonville, AE
#
#
# Insurance underwriter
# Patterson-Singh
#
#         East Thomas, AE
#
#
# Engineer, automotive
# Martinez-Berry
#
#         New Jeffrey, AP
#
#
# Producer, radio
# May, Taylor and Fisher
#
#         Davidside, AA
#
#
# Dispensing optician
# Bailey, Owen and Thompson
#
#         Jamesville, AA
#
#
# Designer, fashion/clothing
# Vasquez Ltd
#
#         New Kelly, AP
#
#
# Chartered loss adjuster
# Leblanc LLC
#
#         Lake Antonio, AA
#
#
# Back-End Web Developer (Python, Django)
# Jackson, Ali and Mckee
#
#         New Elizabethside, AA
#
#
# Forest/woodland manager
# Blankenship, Knight and Powell
#
#         Millsbury, AE
#
#
# Clinical cytogeneticist
# Patton, Haynes and Jones
#
#         Lloydton, AP
#
#
# Print production planner
# Wood Inc
#
#         Port Jeremy, AA
#
#
# Systems developer
# Collins Group
#
#         New Elizabethtown, AA
#
#
# Graphic designer
# Flores-Nelson
#
#         Charlesstad, AE
#
#
# Writer
# Mitchell, Jones and Olson
#
#         Josephbury, AE
#
#
# Field seismologist
# Howard Group
#
#         Seanfurt, AA
#
#
# Chief Strategy Officer
# Kramer-Edwards
#
#         Williambury, AA
#
#
# Air cabin crew
# Berry-Houston
#
#         South Jorgeside, AP
#
#
# Python Programmer (Entry-Level)
# Mathews Inc
#
#         Robertborough, AP
#
#
# Warden/ranger
# Riley-Johnson
#
#         South Saratown, AP
#
#
# Sports therapist
# Spencer and Sons
#
#         Hullview, AA
#
#
# Arts development officer
# Camacho-Sanchez
#
#         Philipland, AP
#
#
# Printmaker
# Oliver and Sons
#
#         North Patty, AE
#
#
# Health and safety adviser
# Eaton PLC
#
#         North Stephen, AE
#
#
# Manufacturing systems engineer
# Stanley-Frederick
#
#         Stevensland, AP
#
#
# Programmer, applications
# Bradley LLC
#
#         Reyesstad, AE
#
#
# Medical physicist
# Parker, Goodwin and Zavala
#
#         Bellberg, AP
#
#
# Media planner
# Kim-Miles
#
#         North Johnland, AE
#
#
# Software Developer (Python)
# Moreno-Rodriguez
#
#         Martinezburgh, AE
#
#
# Surveyor, land/geomatics
# Brown-Ortiz
#
#         Joshuatown, AE
#
#
# Legal executive
# Hartman PLC
#
#         West Ericstad, AA
#
#
# Librarian, academic
# Brooks Inc
#
#         Tuckertown, AE
#
#
# Barrister
# Washington-Castillo
#
#         Perezton, AE
#
#
# Museum/gallery exhibitions officer
# Nguyen, Yoder and Petty
#
#         Lake Abigail, AE
#
#
# Radiographer, diagnostic
# Holder LLC
#
#         Jacobshire, AP
#
#
# Database administrator
# Yates-Ferguson
#
#         Port Susan, AE
#
#
# Furniture designer
# Ortega-Lawrence
#
#         North Tiffany, AA
#
#
# Ship broker
# Fuentes, Walls and Castro
#
#         Michelleville, AP

# %% [markdown]
# # testing

# %%
import requests
from bs4 import BeautifulSoup

url = "https://mtgdecks.net/Commander/tournaments"

response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")

results = soup.find()

# # Find all the tournament rows in the table
# tournament_rows = soup.find_all("tr", class_="altrow")

# # Loop through each tournament row and extract the relevant data
# for row in tournament_rows:
#     tournament_date = row.find("td", class_="date").text.strip()
#     tournament_name = row.find("td", class_="name").text.strip()
#     tournament_location = row.find("td", class_="location").text.strip()
#     tournament_format = row.find("td", class_="format").text.strip()
#     tournament_url = row.find("td", class_="name").find("a")["href"]

#     # Do something with the data (e.g. print it)
#     print(f"Date: {tournament_date}")
#     print(f"Name: {tournament_name}")
#     print(f"Location: {tournament_location}")
#     print(f"Format: {tournament_format}")
#     print(f"URL: {tournament_url}")

# %%
results.find_all('a')
# Out:
# []

# %%
soup.find_all("tr", class_="hidden-xs")
# Out:
# []

# %%
soup.find_all('h1')
# Out:
# []

# %%
soup.p

# %%
print(results.prettify())
# Out:
# <html lang="en-US">
#  <head>
#   <title>
#    Just a moment...
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex,nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
#  </head>
#  <body class="no-js">
#   <div class="main-wrapper" role="main">
#    <div class="main-content">
#     <noscript>
#      <div id="challenge-error-title">
#       <div class="h2">
#        <span class="icon-wrapper">
#         <div class="heading-icon warning-icon">
#         </div>
#        </span>
#        <span id="challenge-error-text">
#         Enable JavaScript and cookies to continue
#        </span>
#       </div>
#      </div>
#     </noscript>
#     <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/managed/nojs/transparent.gif?ray=7ae118b7ef7bc3b1')">
#     </div>
#     <form action="/Commander/tournaments?__cf_chl_f_tk=hKEh24eK1HRijIlRUXFiEnBiD2X7uKuk0fMM4Ch_x1Y-1679851564-0-gaNycGzNCrs" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#      <input name="md" type="hidden" value="Ex2FMrNsZ.hATunRWQ0i_3OTLZsEYOomKNeETwr9CMs-1679851564-0-AfhLIlmrGf0mRaRWrCVEYuIWZQ3zmI39vdFk-otQciDHTT0sXcbv7_z4nUVn0OXY3Qog0duetyv2GEnLRIy8QXazGRYFeDXZxwLVcVUfNWg3c0E61yzwG_t8Ovu-r1eHBmn7K_pvge65AQNcXTiJqNrvDrJk6I1ps6PTOppedmCi9GZC3rZYqunI4fRmRG02VAYeG-2R-Fu-Y8ge6zhqAM_WnrTJaJBB66nZr4Xpuv5dE5zAdaUHdOlWVNU6LoDA5VD_t_NxHM2NMCHZQgAraieETcYr_zsM2keGhfVfWrKP2XnLVK9RGnSoqlswxjm6JMEKqyZeUCErliSYjJ_Gkeid5A9EWl_huCHxbeugDnM8sXLIKGX6kYy-OfhBFMLtMqWl7Fdkctd3bFDVuOuUOjBmN1_8mr6hGZhULoh04eve6n66KkXZ4VOYPqTIEIjHaeD8o4Sf6JJQ5egyo4yzqKk3QgjVyCTtBYPMi9Da1ihHznbm8lQPJUwX2obsfdMESPnWFdw_rmSt4Zz0m3e8ycIYIYyLfjygSOm6g74KB-5V1HyZTCnvywN_2Crt3qg1zHfdyh2t86AMZzgNu1vHg4BPJ2enrzgCdlVUZFlk9D8YeTETM6ouVMJnyFg322kpohHRAtuwEMdUYpAPZy-RGchHQEOCUYvd8P-nkWVsxz2Ghm0YrvCo3vyNBBoqYxxglfRqVlIrnOi1KAoVJTW3gL0gA2n953KJyvyZmWOzNjZccT4vP1qPqG3KWbzp1xKUKDhfi5sJWoAvnPLkOT5m0qX0wH8f9GKYkHw_IFxEOmkX2GXxinu8qoen9CaIdBBvMr8gefYR7d_1Imrv6Y86c0I_Mex8Qoh-tgmhoFCJa9cY3rF2r98W3vHL_OdtSxggN2-moCx3v7VlHp0whhBc6FF3uHp7Do7ewcXruvqQ0bO4HlXKUyZw4Jd4f7Q_AljU-bqeUizKFXh6OfUP_27BcLbjUORkrtmflhFMHIuI9KWSCILpm1dXqxr3BWH9yM3P_y24VIJPt0gSvebPw8bukHjcKQAggmwaCgLPelxtswaDQAWv_f15NZQDEFjLqp14P6HPWOtTrkFXERbJGUWod9DCYqDdsBngW1yudjqJMF2h2YJsUDC2ULIfb4-sduz5sBGSR2azGQiem0FiOkqR0cLX4zlXw40mnIh3He3a4bTubfTgtyzbKt1t_ciPeGMD5Z_-6JRo1eHHrFasSGfGfkVMymWHquwQKBXF0Ajh3JG12YJqX0nHvWBtqTNBt2KIPm2b6bl7sB-rv71jFJC3cJC2jc11iS8BjMwlo0eFTQH-xHmmPKsjy8rWOX4a0IxGx3FWbKnffBpm8V6SGTFjHUHO6xYEvNLZQIus_qsLaEqO5ErzlobzS0XoROIBmksRifYGDoZCvDBc_er85oJvIoNljgRNziLXX_dCx6roakrKE1eIYgxEWd3cIigi9lzR-pMZ4OcI9sLsE7b_ojezD7Pl0XVAm8EMbDtz54OxBkS_7GjaEl4SuCdJs1W7Ta4Y2GOpW3GacTpGixuC-ZLbVSm9uckv5zjx5hGtTDGrzT1zTsnCN7N46PfDqAns_2VnqoMbT-Gdd8n8kix0QLXW4O1m14-E_Mbhxguqu6Eqg7APldfpRDGx0aQoLunZqevw3mmGN0adQJYHkextRA4hZZPZ2grKQoWmYGiGCsX7ovW1oCK-LPr105INafNiPNloZQzJBTEURokTNphozlhFdgJgy7OKUmQHRKVsoTamzPcWl3a5JSJi0EIvoUgx-zLYr2gxX8eEaFSgcxDoUVnkHe72rFvC7hddOmULczZ3z5AqT2Ry0Ac_zeQz0F7XmwYGeLvFV02h4CO7AFOhqE5jcEuPUS9F90ur3IgZvMXYrb78MkZsAic293Due2dbTu4dfIlj_VQTVp9uXeFTFxrZ-LyPNeO_CPKEAV1qEiQkconwCzErQjkotqAZlR_23lS1v2FHJjqfroI2tzEjxDQXOOChqRmomFeliYdqxoFg28ijN7B5bzAnfoVwXQws_SDamIOFvh6yB4C7-EVkhdKqNN6fh1j9u0k88Y85SHMSCjG6pErTxxK8yy6UqJvFYL9gW_HDxtFi_5hJsvzxhHXB7Y1czlak-Yk2FGQiIJEZgscAVfKZPP9HhoAKnvl38_UHDIzvAp45l4ALICeLY_w5wNzuZImENOGoIUSsZa_npZ1Kh73x3ejwXAkaibh-he_GN9pi0MZozGnokvFGpY4wy_O6eppq1npTe4UcDmHVTx4EC4rMNEmP9zU4OV822iCJbITgYy5Suc-Yt4WvhvSM2xKKPKN9NWpXHzsVFFm2mMBC97cDwuPKg0y8YhHSN1mjFeBxAZY3TJQ-nUHQtuv-mbHKfUpdda0XGnbaKyu7WRZFhZERB5Vuy0QOtAtv70Jt3Aj4XhpJU6YPiGL9N6OzyHRk12e8ibKOGA84URWSh2uhAP1r3THbmHVQy4m0zN_s3bHeZs_2_C977Q-qsD4DtKEbkFmYn1F6pjjqoZ77rqQCz-agmxbBdEhfdHgHw6fpFGvcaVzn6GbXFjMa5C514OHzCIjt2BsVpoRJ_WGxwdpwjD5xev1BGhwEOhhQZQqV3FiISOms91H5aWfxW2hVyty_hLPo3gG6jq5Wn2tf52tWFa7SvWeBGSxRzDkiQGYe1g"/>
#     </form>
#    </div>
#   </div>
#   <script>
#    (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cZone: 'mtgdecks.net',
#             cType: 'managed',
#             cNounce: '62746',
#             cRay: '7ae118b7ef7bc3b1',
#             cHash: 'd6ed5a580b93aad',
#             cUPMDTk: "\/Commander\/tournaments?__cf_chl_tk=hKEh24eK1HRijIlRUXFiEnBiD2X7uKuk0fMM4Ch_x1Y-1679851564-0-gaNycGzNCrs",
#             cFPWv: 'b',
#             cTTimeMs: '1000',
#             cMTimeMs: '0',
#             cTplV: 5,
#             cTplB: 'cf',
#             cK: "",
#             cRq: {
#                 ru: 'aHR0cHM6Ly9tdGdkZWNrcy5uZXQvQ29tbWFuZGVyL3RvdXJuYW1lbnRz',
#                 ra: 'cHl0aG9uLXJlcXVlc3RzLzIuMjguMQ==',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY3OTg1MTU2NC43ODUwMDA=',
#                 m: '1N0xmlNHcBWeRrM4neUgYL5uzXPPWPfCDDVY2iUjNzo=',
#                 i1: 'Q2HczVv7iQ5VQLOaH8u2Ug==',
#                 i2: '9lehXwARMdlMETstaHcVqg==',
#                 zh: 'E1sOE47J/NwOldWxeIJpiiKaYY34wZRmhNkq6w3XN2w=',
#                 uh: 'SLdVolODg++SO356HusO5I/hbfOpiiOxQXj62i/MUkA=',
#                 hh: 'Odc0WggcL1KnIpiAZ+Yz+K13c5TnxM0zZFQfgrM8I80=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/managed/js/transparent.gif?ray=7ae118b7ef7bc3b1');
#         trkjs.setAttribute('alt', '');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/b/orchestrate/managed/v1?ray=7ae118b7ef7bc3b1';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, location.href.length - window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/Commander\/tournaments?__cf_chl_rt_tk=hKEh24eK1HRijIlRUXFiEnBiD2X7uKuk0fMM4Ch_x1Y-1679851564-0-gaNycGzNCrs" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#   </script>
#  </body>
# </html>
